# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikila-K/Assignments/blob/main/Assignment_Measures.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-659d7aff-2fd8-4ff0-9643-aa6ca4baa0c6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-659d7aff-2fd8-4ff0-9643-aa6ca4baa0c6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data=pd.read_csv('StudentsPerformance.csv')

# %%
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group C            some high school  free/reduced
# 1  female        group B                 high school  free/reduced
# 2  female        group B            some high school  free/reduced
# 3  female        group B                some college      standard
# 4  female        group C                some college  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none           0             17             10
# 1                    none           8             24             23
# 2                    none          18             32             28
# 3                    none          11             38             32
# 4                    none          22             39             33

# %% [markdown]
# 1.Count of males and females participated in the test
#
# ---

# %%
data['gender'].value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %% [markdown]
# 2.Parental level of education

# %%
data['parental level of education'].value_counts()
# Out:
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: parental level of education, dtype: int64

# %%
data['parental level of education'].mode()
# Out:
# 0    some college
# dtype: object

# %% [markdown]
# #Most of the parents have done some college level education.Parents who have master's degree is the least#

# %% [markdown]
# 3. Average for math,reading and writing

# %%
data['Average']=data['math score']+data['reading score']+data['writing score']/3

# %%
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group C            some high school  free/reduced
# 1  female        group B                 high school  free/reduced
# 2  female        group B            some high school  free/reduced
# 3  female        group B                some college      standard
# 4  female        group C                some college  free/reduced
#
#   test preparation course  math score  reading score  writing score    Average
# 0                    none           0             17             10  20.333333
# 1                    none           8             24             23  39.666667
# 2                    none          18             32             28  59.333333
# 3                    none          11             38             32  59.666667
# 4                    none          22             39             33  72.000000

# %%
sum(data['math score'],data['reading score'])
# Out:
# 0      66018
# 1      66025
# 2      66033
# 3      66039
# 4      66040
#        ...
# 995    66088
# 996    66097
# 997    66098
# 998    66101
# 999    66101
# Name: reading score, Length: 1000, dtype: int64

# %%
data.groupby('gender')[['reading score','writing score']].mean()
# Out:
#         reading score  writing score
# gender
# female      72.590734      72.467181
# male        65.545643      63.446058

# %%
data.groupby('test preparation course')[['reading score','writing score']].mean()
# Out:
#                          reading score  writing score
# test preparation course
# completed                    74.175978      74.684358
# none                         66.417445      64.457944

# %% [markdown]
# 4.Scoring Variation

# %%
data.var()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# math score        242.411410
# reading score     216.279254
# writing score     231.842682
# Average          1125.929168
# dtype: float64

# %%
data.groupby('gender').var()
# Out:
#         math score  reading score  writing score      Average
# gender
# female  256.958593     207.677438     220.369327  1187.689356
# male    211.889097     200.211010     202.413924  1050.870271

# %%
data.groupby('test preparation course').var()
# Out:
#                          math score  reading score  writing score      Average
# test preparation course
# completed                210.884027     183.265864     175.202612   932.805332
# none                     246.668662     213.419851     226.251739  1127.383766

# %%
data.std()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# math score       15.569567
# reading score    14.706436
# writing score    15.226381
# Average          33.554868
# dtype: float64

# %%
data.groupby('gender').std()
# Out:
#         math score  reading score  writing score    Average
# gender
# female   16.029928      14.411018      14.844842  34.462869
# male     14.556411      14.149594      14.227225  32.417129

# %%
data.groupby('test preparation course').std()
# Out:
#                          math score  reading score  writing score    Average
# test preparation course
# completed                 14.521847      13.537572      13.236412  30.541862
# none                      15.705689      14.608896      15.041667  33.576536

# %% [markdown]
# 5. 25% of students based on math score

# %%
data['math score'].quantile(.75)
# Out:
# 77.0
